# %%
# Pandas
import pandas as pd
data={'Name': ['Alice', 'Bob', 'Charlie'], 'Age': [25, 30, 35]}
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35

# %%
# .csv -> read_csv excel(.xlsx)->read_excel, read_xlsx

# data collection
data=pd.read_csv('C:/Users/Admin/Downloads/CHV APPS.csv')
print(data)
# Out:
#             Timestamp                    Name Branch  Year Phone Number  \
# 0   8-4-2025 12:01:23                   Joshi    Cse     4  93471715051
# 1   8-5-2025 15:08:05      Chitrada jyoshika     ECE     3   7396410015
# 2   8-5-2025 15:08:15           P.Karuna babu    Ece     3   7981799375
# 3   8-5-2025 15:08:17         Jeevana prasad    ECE      3   9441461577
# 4   8-5-2025 15:08:27          Gudiya Pujitha    Ece     3   9515081608
# ..                ...                     ...    ...   ...          ...
# 91  8-5-2025 15:16:48         L.Bhavana priya   ECE      3   9030834546
# 92  8-5-2025 15:17:10            B. Yernibabu    Ece     3   8688015155
# 93  8-5-2025 15:17:34  Ch Gopi Vallaba kumar     ECE     3   7287934741
# 94  8-5-2025 15:19:22   Shaik Mahamad Thahir     ECE     3   7569993613
# 95  8-5-2025 15:28:23            M Bhavya Sri    Ece     3   8639471088
#
#                                           email Interested in Internnship  \
# ...

# %%
# Data Preprocessing
data.head()  # first 5 rows
# Out:
#            Timestamp                Name Branch  Year Phone Number  \
# 0  8-4-2025 12:01:23               Joshi    Cse     4  93471715051
# 1  8-5-2025 15:08:05  Chitrada jyoshika     ECE     3   7396410015
# 2  8-5-2025 15:08:15       P.Karuna babu    Ece     3   7981799375
# 3  8-5-2025 15:08:17     Jeevana prasad    ECE      3   9441461577
# 4  8-5-2025 15:08:27      Gudiya Pujitha    Ece     3   9515081608
#
#                           email Interested in Internnship  \
# 0     joshisankar5051@gmail.com                       yes
# 1  jyoshikachitrada21@gmail.com                       yes
# 2      pudikarunababu@gmail.com                        No
# 3    jeevanprasad8096@gmail.com                       yes
# 4       gudiyapujitha@gmail.com                       yes
#
#             Internship Offered Interested in course  \
# 0              App Development                  Yes
# 1  Full Stack  Web Development                  Yes
# ...

# %%
data.tail()  # last 5 rows
# Out:
#             Timestamp                    Name Branch  Year Phone Number  \
# 91  8-5-2025 15:16:48         L.Bhavana priya   ECE      3   9030834546
# 92  8-5-2025 15:17:10            B. Yernibabu    Ece     3   8688015155
# 93  8-5-2025 15:17:34  Ch Gopi Vallaba kumar     ECE     3   7287934741
# 94  8-5-2025 15:19:22   Shaik Mahamad Thahir     ECE     3   7569993613
# 95  8-5-2025 15:28:23            M Bhavya Sri    Ece     3   8639471088
#
#                                           email Interested in Internnship  \
# 91        lenkabhavanapriya.23.ece@anits.edu.in                       yes
# 92                  yernibabubarala39@gmail.com                       yes
# 93  chendagopivallabhakumar.23.ece@anits.edu.in                        No
# 94                     shaikthahir981@gmail.com                        No
# 95                 maddalabhavyasri06@gmail.com                       yes
#
#              Internship Offered Interested in course  \
# ...

# %%
data.shape  # (rows, columns)
# Out:
# (96, 14)

# %%
data.info()  # summary
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Timestamp                  96 non-null     object
#  1   Name                       96 non-null     object
#  2   Branch                     96 non-null     object
#  3   Year                       96 non-null     int64
#  4   Phone Number               96 non-null     object
#  5   email                      96 non-null     object
#  6   Interested in Internnship  96 non-null     object
#  7   Internship Offered         96 non-null     object
#  8   Interested in course       96 non-null     object
#  9   Courses Offered            96 non-null     object
#  10  How is the Session         96 non-null     object
#  11  How do you Rate us         96 non-null     int64
#  12  Anything to Say?           96 non-null     object
# ...

# %%
data.isnull()  # missing values per column
# Out:
#     Timestamp   Name  Branch   Year  Phone Number  email  \
# 0       False  False   False  False         False  False
# 1       False  False   False  False         False  False
# 2       False  False   False  False         False  False
# 3       False  False   False  False         False  False
# 4       False  False   False  False         False  False
# ..        ...    ...     ...    ...           ...    ...
# 91      False  False   False  False         False  False
# 92      False  False   False  False         False  False
# 93      False  False   False  False         False  False
# 94      False  False   False  False         False  False
# 95      False  False   False  False         False  False
#
#     Interested in Internnship  Internship Offered  Interested in course  \
# 0                       False               False                 False
# 1                       False               False                 False
# ...

# %%
data.isnull().sum()  # missing values per column
# Out:
# Timestamp                     0
# Name                          0
# Branch                        0
# Year                          0
# Phone Number                  0
# email                         0
# Interested in Internnship     0
# Internship Offered            0
# Interested in course          0
# Courses Offered               0
# How is the Session            0
# How do you Rate us            0
# Anything to Say?              0
# Status                       94
# dtype: int64

# %%
data1=data['Year']
data1.head()
# Out:
# 0    4
# 1    3
# 2    3
# 3    3
# 4    3
# Name: Year, dtype: int64

# %%
data1=data[data['Year']==3]
print(data1.head())
# Out:
#            Timestamp                Name Branch  Year Phone Number  \
# 1  8-5-2025 15:08:05  Chitrada jyoshika     ECE     3   7396410015
# 2  8-5-2025 15:08:15       P.Karuna babu    Ece     3   7981799375
# 3  8-5-2025 15:08:17     Jeevana prasad    ECE      3   9441461577
# 4  8-5-2025 15:08:27      Gudiya Pujitha    Ece     3   9515081608
# 5  8-5-2025 15:08:28             Bhavana    Ece     3   8523815932
#
#                           email Interested in Internnship  \
# 1  jyoshikachitrada21@gmail.com                       yes
# 2      pudikarunababu@gmail.com                        No
# 3    jeevanprasad8096@gmail.com                       yes
# 4       gudiyapujitha@gmail.com                       yes
# 5    bathulabhavana98@gmail.com                       yes
#
#             Internship Offered Interested in course  \
# 1  Full Stack  Web Development                  Yes
# 2          NA (NOT APPLICABLE)                  Yes
# ...

# %%
data1=data[data['Courses Offered']=='Full Stack  Web Development']
data1.head()
# Out:
#             Timestamp             Name Branch  Year Phone Number  \
# 3   8-5-2025 15:08:17  Jeevana prasad    ECE      3   9441461577
# 6   8-5-2025 15:08:36  Turala Yogitha     Ece     3   7032701602
# 10  8-5-2025 15:08:54    Komali ganta     Exe     3   8374494673
# 16  8-5-2025 15:09:20   GUDALA PRADEEP    Ece     3   7702890179
# 17  8-5-2025 15:09:23  K.dhana sekhar     Ece     3   6305298838
#
#                                 email Interested in Internnship  \
# 3          jeevanprasad8096@gmail.com                       yes
# 6             yogithaturala@gmail.com                       yes
# 10            Gantakomali06@gmail.com                       yes
# 16  gudalapradeep.23.ece@anits.edu.in                       yes
# 17           sekhardhana765@gmail.com                       yes
#
#              Internship Offered Interested in course  \
# 3   Full Stack  Web Development                  Yes
# 6   Full Stack  Web Development                  Yes
# ...

# %%
data['Courses Offered'].unique()  # unique values in column
# Out:
# array(['App Development', 'Programming', 'Full Stack  Web Development',
#        'AI', 'Data Science', 'NA (NOT APPLICABLE)', 'Cyber Security'],
#       dtype=object)

# %%
data['How is the Session'].unique()  # unique values in column
# Out:
# array(['Good', 'Understadable', 'Not Good'], dtype=object)

# %%
data.duplicated()  # duplicated rows
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 91    False
# 92    False
# 93    False
# 94    False
# 95    False
# Length: 96, dtype: bool

# %%
data.duplicated().sum()  # duplicated rows
# Out:
# np.int64(0)

# %%
# Data Visualization
